# %%
import pandas as pd
import numpy as np

# %%
from src.importacao.economatica.iochpe_dados_anuais import IochpeDadosAnuais

# %%
ida = IochpeDadosAnuais(2009, 2020)

# %%
ida.df2.loc[('bp', 'ativo', 'circulante')]
# Out:
# <ipython-input-12-d4864143800e>:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   ida.df2.loc[('bp', 'ativo', 'circulante')]
#                                                                                      conta  \
# codigo_3               codigo_4 codigo_5 codigo_6 codigo_7
# aplicacoes_financeiras NaN      NaN      NaN      NaN               Aplicacoes financeiras
# ativos_biologicos      NaN      NaN      NaN      NaN                 Ativos Biologicos CP
# caixa_e_equivalentes   NaN      NaN      NaN      NaN        Caixa e equivalentes de caixa
# contas_a_receber       NaN      NaN      NaN      NaN                  Contas a receber CP
# despesas_antecipadas   NaN      NaN      NaN      NaN               Despesas pagas antecip
# estoques               NaN      NaN      NaN      NaN                             Estoques
# impostos_a_recuperar   NaN      NaN      NaN      NaN                 Impostos a Recuperar
# ...

# %%
filter = ida.df2.index.dropna(how='all')

# %%
filter
# Out:
# MultiIndex([('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
#             ('bp',                                'ativo', ...),
# ...

# %%
df = ida.df2.loc[filter]

# %%
df
# Out:
#                                                                                                                                                conta  \
# codigo_0 codigo_1           codigo_2                      codigo_3               codigo_4 codigo_5 codigo_6 codigo_7
# bp       ativo              circulante                    aplicacoes_financeiras NaN      NaN      NaN      NaN               Aplicacoes financeiras
#                                                           ativos_biologicos      NaN      NaN      NaN      NaN                 Ativos Biologicos CP
#                                                           caixa_e_equivalentes   NaN      NaN      NaN      NaN        Caixa e equivalentes de caixa
#                                                           contas_a_receber       NaN      NaN      NaN      NaN                  Contas a receber CP
# ...
